# %% [markdown]
# # MATPLOTLIB
# https://matplotlib.org/

# %%
#!pip install matplotlib
#!pip install seaborn
#!pip install ipympl

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl #versiyon kontrol, default degerlere donme vs icin
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#matplotlib varsayılan olarak arka planda çalışır ve grafikler, ayrı bir pencere veya dosya olarak kaydedilmedikçe görüntülenmez.
#%matplotlib inline komutunu kullanarak matplotlib grafiklerinin notebookda doğrudan görüntülenmesini sağlarız
#%matplotlib notebook
import warnings; # yukaridaki gibi hata mesajlarini almamak icin
warnings.filterwarnings("ignore")

# %%
print(mpl.__version__)
# Out:
# 3.7.0

# %% [markdown]
# ## Figure an Axes

# %%
x = np.arange(0,10)
y = x*2
plt.plot(x,y)
plt.show()

# %%
print(plt.style.available) # grafigimizin arka fonu ile ilgili kullanbilecegimiz methodlari gosterir
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
x = np.arange(0,10)
y = x*2
plt.style.use('seaborn-v0_8')
plt.plot(x,y)
plt.show()

# %%
x = np.arange(0,10)
y = x*2
plt.figure(figsize = (4,2))
# grafigin boyutunu ayarlar ve bos bir cerceve olusturur
# bu yuzden plt.plot(x,y) grafik adindan once yazariz
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Grafiklere Arguman Verme

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.figure(figsize = (8,6))
plt.plot(x,y,'r*') # r--> red in r si
plt.show()

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize = (10,5))
plt.plot(x,y,"*g")

plt.xlabel("X - Axis")
plt.ylabel("Y - Axis")
plt.title("AXES");

# %% [markdown]
# ## Coklu Data ve Legend Verme

# %%
age = np.arange(25, 44, 2.5)
salary = np.arange(40000, 76000, 5000)
salary2 = [45372, 46852, 69401, 56790, 73000, 75000, 80000, 83454]

# %%
print(len(age))
print(len(salary))
print(len(salary2))
# eleman sayilari esit olmazsa esleme yapamaz ve hata verir grafik cizilmez
# Out:
# 8
# 8
# 8

# %%
plt.plot(age,salary,"b:", label = "Salary")
plt.plot(age,salary2,"r:", label = "Salary2")

plt.xlabel("Age")
plt.ylabel("Salary")
plt.legend() # etiketleri(labels) gormek isteresek legend() methodunu kullanmaliyiz
plt.title("Salary By Age")
# Out:
# Text(0.5, 1.0, 'Salary By Age')

# %%
# %matplotlib notebook
age = np.arange(25, 44, 2.5)
salary = np.arange(40000, 76000, 5000)
salary2 = [45372, 46852, 69401, 56790, 73000, 75000, 80000, 83454]
plt.plot(age, salary, "b:", label = "Salary")  # :  ... anlamında
plt.plot(age, salary2, "r-", label = "Salary2")

plt.xlabel("Age")
plt.ylabel("Salary, TL")
plt.legend()
plt.title("SALARY BY AGE");
# Out:
# <div id='cf26f34a-54d3-4c9e-b2dd-6fafba5c12e2'></div>

# %%
# %matplotlib inline
age = np.arange(25, 44, 2.5)
salary = np.arange(40000, 76000, 5000)
salary2 = [45372, 46852, 69401, 56790, 73000, 75000, 80000, 83454]
plt.figure(figsize = (6,4))
plt.plot(age, salary, "b:", label = "Salary")  # :  ... anlamında
plt.plot(age, salary2, "r-", label = "Salary2")

plt.xlabel("Age")
plt.ylabel("Salary, TL")
plt.legend(loc=2) # legend() icindeki parametreler ile labellarin yerlerini degistirebiliriz
# bbox_to_anchor=(0.0,0.0,0.9,0.9) #ilk iki deger ile figure de gezebilirken son iki degerde axes te gezeriz..ince ayar yapar
plt.title("SALARY BY AGE");
# Out:
# <div id='9bd39f84-0113-4b70-b8c3-0706a200c085'></div>

# %% [markdown]
# ## Figur ve Axes Renklendirme

# %%
plt.figure(facecolor = "yellow", figsize = (10, 5)) #burada figure u renklendirdik ve boyutlandirdik
ax = plt.axes() # burada axes i ele aldik ax a atadik
ax.set_facecolor("xkcd:mint green") #axes i renklendirdik
plt.plot(age, salary, "b:", label = "Salary") # setting up legends linewidth = lw
plt.plot(age, salary2, "r-", label = "Salary2") # setting up legends ls = linestyle
plt.xlabel ("Age")
plt.ylabel("Salary")
plt.legend(loc = "right")
plt.title("SALARY BY AGE");

# %%
plt.figure(facecolor = "yellow", figsize = (10, 5)) #burada figure u renklendirdik ve boyutlandirdik
ax = plt.axes() # burada axes i ele aldik ax a atadik
ax.set_facecolor("xkcd:mint green") #axes i renklendirdik
plt.plot(age, salary, "b-", linewidth= 4, label = "Salary") # setting up legends linewidth = lw ,linewidth= 4 cizgilerin kalinligini ayarlar
plt.plot(age, salary2, "r", ls="-.", label = "Salary2") # setting up legends ls = linestyle, ls="-." cizgilerin style ini ayarlar
plt.xlabel ("Age")
plt.ylabel("Salary")
plt.legend(loc = "right")
plt.title("SALARY BY AGE");

# %% [markdown]
# ## Functional Methods & Object Oriented Methods

# %% [markdown]
# ### Functional Methods

# %%
age = np.arange(25,44, 2.5)
salary = np.arange(40000, 76000, 5000)
salary_2 = [45372, 48876, 53850, 57287,
            65998, 71496, 75370, 83640]
plt.style.use("seaborn-dark")
plt.plot(age, salary)
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("SALARY BY AGE")
plt.grid(color="purple") # style i gridli olanlarda gridleri modifiye edebiliriz(grid=izgara)
plt.show()

# %% [markdown]
# ### OOM(Object Oriented Method)

# %%
plt.style.use("seaborn-darkgrid")
fig, ax = plt.subplots()
ax.plot(age, salary, "r")
ax.set_xlabel("Age")
ax.set_ylabel("Salary")
ax.set_title("SALARY BY AGE");

# %% [markdown]
# ## Functional Method Multi Plot

# %%
plt.subplot(2, 1, 1)
plt.plot(age, salary, "r")
plt.subplot(2, 1, 2)
plt.plot(age, salary2, "g");

# %% [markdown]
# ## OOM Multi Plot

# %%
fig, ax = plt.subplots(2, 1)
ax[0].plot(age, salary, "r")
ax[1].plot(age, salary2, "g")
plt.tight_layout(); # Grafiklerin birbiri içine geçmesini engelliyor.

# %% [markdown]
# ## Functional Method Multi Plot =(2 rows 3 columns toplam 6 axes)

# %%
plt.subplot(2, 3, 1)
plt.plot(age, salary, "r")
plt.subplot(2, 3, 2)
plt.plot(age, salary2, "g")
plt.subplot(2, 3, 3)
plt.plot(age, salary, "y")
plt.subplot(2, 3, 4)
plt.plot(age, salary, "bo")
plt.subplot(2, 3, 5)
plt.plot(age, salary, "b")
plt.subplot(2, 3, 6)
plt.plot(age, salary2, "black")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### OOM Multi Plot(2 rows 3 columns 6 axes)

# %%
mpl.rcParams.update(mpl.rcParamsDefault) ## Grafiklerdeki tüm modifikasyonları default değerlere döndürdük
fig, ax = plt.subplots(2, 3)
ax[0][0].plot(age, salary, "r")
ax[0][1].plot(age, salary2, "g")
ax[0][2].plot(age, salary, "y")
ax[1][0].plot(age,salary,"bo")
ax[1][1].plot(age,salary,"b")
ax[1][2].plot(age,salary2,"c")
fig.tight_layout()
plt.show()

# %%
x = np.arange(0, 30, 0.2)
fig, ax = plt.subplots(figsize = (14, 8))
ax.plot(x, x-1, color = "green", linewidth = 3, linestyle = "-")
ax.plot(x, x-2, color = "red", lw = 3, linestyle = "-.")
ax.plot(x, x-3, color = "yellow", lw = 3, ls = ":")
ax.plot(x, x-4, color = "purple", linewidth = 3, linestyle = "--")
plt.show()

# %%
x = np.arange(10)
fig, ax = plt.subplots(2, 2, figsize = (12,6))
plt.suptitle("LineStyles & Markers & Markersize & Color", fontsize = 16, y = 0.93)
ax[0, 0].plot(x, "r", marker= "+", markersize = 5)
ax[0, 1].plot(x-2, "y", marker= "o", ms = 5)
ax[1, 0].plot(x-3, "black", marker= "s", ms = 5, lw = 5)
ax[1, 1].plot(x-4, "g", marker= "1", ms = 5)
plt.show()

# %%
x = np.arange(-50, 50)
y1 = np.power(x, 2)
y2 = np.power(x, 3)
y3 = np.sin(x)
y4 = np.cos(x)
y5 = np.tan(x)
y6 = np.tanh(x)
y7 = np.sinh(x)
y8 = np.cosh(x)
y9 = np.exp(x)
fig1, ax1 = plt.subplots(nrows = 3, ncols = 3, figsize= (20, 20))
ax1[0, 0].plot(x, y1, "tab:blue") # set the color of line chart
ax1[0, 0].set_title("Square Function") # setting title of subplot
ax1[0, 0].set_xlabel("X", fontsize = 18)
ax1[0, 0].set_ylabel("Y", fontsize = 18)
ax1[0, 1].plot(x, y2, "tab:orange") # set the color of line chart
ax1[0, 1].set_title("Cubic Function") # setting title of subplot
ax1[0, 1].set_xlabel("X", fontsize = 18)
ax1[0, 1].set_ylabel("Y", fontsize = 18)
ax1[0, 2].plot(x, y3, "tab:green") # set the color of line chart
ax1[0, 2].set_title("Sine Function") # setting title of subplot
ax1[0, 2].set_xlabel("X", fontsize = 18)
ax1[0, 2].set_ylabel("Y", fontsize = 18)
ax1[1, 0].plot(x, y4, "r-") # set the color of line chart
ax1[1, 0].set_title("Cosine Function") # setting title of subplot
ax1[1, 0].set_xlabel("X", fontsize = 18)
ax1[1, 0].set_ylabel("Y", fontsize = 18)
ax1[1, 1].plot(x, y5, "b-") # set the color of line chart
ax1[1, 1].set_title("Tangent Function") # setting title of subplot
ax1[1, 1].set_xlabel("X", fontsize = 18)
ax1[1, 1].set_ylabel("Y", fontsize = 18)
ax1[1, 2].plot(x, y6, "g-") # set the color of line chart
ax1[1, 2].set_title("Hyperbolic Tangent Function") # setting title of subplot
ax1[1, 2].set_xlabel("X", fontsize = 18)
ax1[1, 2].set_ylabel("Y", fontsize = 18)
ax1[2, 0].plot(x, y7, "m-") # set the color of line chart
ax1[2, 0].set_title("Hyperbolic Sine Function") # setting title of subplot
ax1[2, 0].set_xlabel("X", fontsize = 18)
ax1[2, 0].set_ylabel("Y", fontsize = 18)
ax1[2, 1].plot(x, y8, "y*") # set the color of line chart
ax1[2, 1].set_title("Hyperbolic Cosine Function") # setting title of subplot
ax1[2, 1].set_xlabel("X", fontsize = 18)
ax1[2, 1].set_ylabel("Y", fontsize = 18)
ax1[2, 2].plot(x, y9, "kv") # set the color of line chart
ax1[2, 2].set_title("Exp Function") # setting title of subplot
ax1[2, 2].set_xlabel("X", fontsize = 18)
ax1[2, 2].set_ylabel("Y", fontsize = 18)
plt.show()

# %% [markdown]
# # Scatter Plot(Sacinti Grafigi)

# %%
# Scatter Plot(Sacinti Grafigi)
#seaborn.scatterplot(data=None, *, x=None, y=None, hue=None, size=None, style=None,
# palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, 
# size_norm=None, markers=True, style_order=None, legend='auto', ax=None, **kwargs)

# %%
mpl.rcParams.update(mpl.rcParamsDefault) ## Grafiklerdeki tüm modifikasyonları default değerlere döndürdük
# %matplotlib inline

# %%
x = np.array([15, 22, 42, 32, 55, 8, 6, 74, 67, 12, 78, 2, 13, 14, 53, 27, 23, 89, 65])
y = np.array([99, 48, 31, 63, 89, 74, 9, 65, 72, 54, 23, 98, 63, 75, 30, 52, 55, 24, 13])

# %%
plt.figure(figsize = (10,5))
plt.scatter(x,y)
plt.show()

# %%
sns.get_dataset_names() #seaborn daki dataset isimlerini getirdi
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips") # dataseti yukledik

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips #ilk 5 ve son 5 satiri bir arada gormek istersek
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.describe().T # Daha kolay anlasilir bir kullanim
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
plt.figure(figsize = (10,5))
plt.scatter(tips["total_bill"],tips["tip"]) #plt.scatter(tips.total_bill,tips.tip)
plt.show()

# %%
# En Kucuk Kareler Yontemi(Ordinary Least Squary

# %%
fig,ax = plt.subplots()
ax.bar(tips.sex, tips.tip) # Kategorik degisken olarak 
plt.show()

# %%
fig,ax = plt.subplots()
ax.barh(tips.sex, tips.tip) #barh-->horizontal(yatay)
plt.show()

# %%
fig,ax = plt.subplots() 
ax.bar(tips.day, tips.total_bill) #barh-->horizontal # gunlere gore hesap tutari
plt.show()

# %% [markdown]
# ## Gunluk Toplam Kazanc Bulma

# %%
total_price_day = tips.groupby("day").sum() # gunlere gore grupladik ve her bir sayisal sutunun toplamlarini buldu
total_price_day.head()
# Out:
#       total_bill     tip  size
# day
# Thur     1096.33  171.83   152
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216

# %%
day = tips.groupby("day").sum().index # yukaridaki tabloda index yerine gecen satir yani indexleri getirdi
day
# Out:
# CategoricalIndex(['Thur', 'Fri', 'Sat', 'Sun'], categories=['Thur', 'Fri', 'Sat', 'Sun'], ordered=False, dtype='category', name='day')

# %%
day_of_total_bill=list(tips.groupby("day")["total_bill"].sum())
day_of_total_bill #gunlere gore toplam kazanci list halinde dondurdu
# Out:
# [1096.33, 325.88, 1778.4, 1627.16]

# %%
fig,ax =

# %%
plt.bar(tips.groupby("day").sum().index, tips.groupby("day")["total_bill"].sum())
plt.show()

# %%
# command --> cuma gunu isler dusuk, o gune kampanya koy

# %%
# for example, 70.000 urunden 5.000' ine odaklan, 1000 tanesi icin reklam cik denmesi sonucu kar %200 artmis

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
day_of_tip = list(tips.groupby("day")["tip"].sum()) # gunluk toplam tip leri cektik
day_of_tip
# Out:
# [171.82999999999998, 51.96, 260.4, 247.39]

# %%
fig,ax =plt.subplots(figsize = (6,3))
ax.bar(day,day_of_tip)
plt.show()

# %%
fig, ax = plt.subplots()
ax.bar(day,day_of_total_bill)
ax.bar(day, day_of_tip)
plt.legend(["day_of_total_bill","day_of_tip"]) # labellari bu sekilde legend() icinde de tanimlayabiliriz
plt.show()

# %%
# command--> cuma gunu satis da tip de az

# %% [markdown]
# # Pie Chart

# %%
x = np.array([100, 100, 100, 100])
mylabels = ["Apples", "Bananas", "Cherries", "Pear"]
plt.figure(figsize=(7, 7))
plt.pie(x, labels = mylabels, labeldistance= -0.70, autopct="%.3f")
# labeldistance=0.85 label larin merkeze olan uzakligini ayarliyor
# labeldistance icin eksi sayi verirsek, tam karsisindaki bolume geciyor,
# yani diagonalinde bulunan degerle yerini degistirir
# autopct="%.2f" kesir kisminda kac rakam gormek istedigimizi ayarlar. Yuvarlamayi matematikdeki sisteme gore yapar
plt.show()

# %%
# ML de iyi model yoktur, best practice yoktur kisiye gore degisebilir onemli olan fikrimizi, tezimizi savunabilmek
# supheye dustugumuz yerde  https://matplotlib.org/stable/galery/index.html e bak

# %%
z = np.array([16, 21,45,19])
mylabels = ["Apples", "Bananas", "Cherries", "Pear"]

myexplode = [0.2, 0, 0, 0] # pie chart dan ayiracagimiz dilimin position ini myexplode variableina atadik

# %%
plt.figure(figsize = (7,7))
plt.pie(z, labels= mylabels , explode = myexplode, labeldistance=0.75 , autopct = "%.1f", startangle = 15)
# explode = parametresi pie chartdan dilim ayirmamizi saglar karsinina position yazilir
# startangle = 180 daire dilimimizin saatyonunun tersinde belirtilen aci kadar dondurur.
# Baslangic noktasi yatay eksen positive taraftir
plt.show()

# %%
plt.figure(figsize=(10,8))
color_list = ["gold","yellowgreen","lightcoral","lightskyblue","lightgreen"] # her birini renklendirmek icin
explode_list = [0.1,0.4,0.3,0.2] # dilimlerin ayrilma positionu 
mylabels = ["Apples","Bananas","Cherries","Pear"]
y =np.array([25,35,25,15])
plt.pie(y, 
        labels=mylabels, # etiket isimleri
        colors=color_list, # dilim renkleri
        explode=explode_list, # dilimlerin positionu
        labeldistance=0.75, #labellarin merkeze olan uzakligi
        autopct="%.1f", #ondalik kismin basamak sayisi ayarlanir
        startangle=90, # daire dilimimizin saatyonunun tersinde belirtilen aci kadar dondurur.
        pctdistance=0.6, #label ile  
        shadow=True) # golgelendirme yapiyor
plt.legend()
plt.show()
